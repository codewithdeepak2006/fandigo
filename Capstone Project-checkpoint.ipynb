# %% [markdown]
# # Capstone Project (movie rating )

# %% [markdown]
# # Part 1

# %%
# IMPORT HERE!
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
# Out:
# <module 'seaborn' from 'C:\\Users\\DEEPAK VERMA\\anaconda3\\Lib\\site-packages\\seaborn\\__init__.py'>

# %%
fandango = pd.read_csv("C:\\Users\\DEEPAK VERMA\\OneDrive\\Desktop\\fandango_scrape.csv")
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %%
plt.figure(figsize=(10,6),dpi=159)
sns.scatterplot(data=fandango,x='RATING',y='VOTES')
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
fandango.drop('FILM',axis=1).corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
title='Film Title Name (Year)'
title.split('(')[-1].replace(')','')
# Out:
# 'Year'

# %%
fandango['YEAR'] = fandango['FILM'].apply(lambda title:title.split('(')[-1].replace(')',''))

# %%
fandango
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %%
fandango['YEAR'].value_counts()
# Out:
# YEAR
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: count, dtype: int64

# %%
sns.countplot(data=fandango,x='YEAR',palette='Dark2')
# Out:
# C:\Users\DEEPAK VERMA\AppData\Local\Temp\ipykernel_15272\2946598728.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=fandango,x='YEAR',palette='Dark2')
# <Axes: xlabel='YEAR', ylabel='count'>

# %%
fandango.nlargest(10,'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
no_votes = fandango['VOTES'] ==0
no_votes
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 499     True
# 500     True
# 501     True
# 502     True
# 503     True
# Name: VOTES, Length: 504, dtype: bool

# %%
no_votes.sum()
# Out:
# 69

# %%
len(fandango[fandango['VOTES']==0])
# Out:
# 69

# %%
fan_reviewed = fandango[fandango['VOTES']>0]
fan_reviewed
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1          Jurassic World (2015)    4.5     4.5  34390  2015
# 2         American Sniper (2015)    5.0     4.8  34085  2015
# 3               Furious 7 (2015)    5.0     4.8  33538  2015
# 4              Inside Out (2015)    4.5     4.5  15749  2015
# ..                           ...    ...     ...    ...   ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015
# 431            The Intern (2015)    5.0     5.0      1  2015
# 432        The Park Bench (2015)    5.0     5.0      1  2015
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015
#
# [435 rows x 5 columns]

# %%
plt.figure(figsize=(10,6),dpi=159)
sns.kdeplot(data= fan_reviewed,x='RATING',clip=[0,5],fill=True,label='True Rating')
sns.kdeplot(data= fan_reviewed,x='STARS',clip=[0,5],fill=True,label='Stars Displayed')
plt.legend()

# %%
fan_reviewed['STARS_DIFF']=fan_reviewed['STARS']-fan_reviewed['RATING']
fan_reviewed
# Out:
# C:\Users\DEEPAK VERMA\AppData\Local\Temp\ipykernel_2064\2240894573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fan_reviewed['STARS_DIFF']=fan_reviewed['STARS']-fan_reviewed['RATING']
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# ...

# %%
plt.figure(figsize=(12,6),dpi=180)
sns.countplot(data=fan_reviewed,x='STARS_DIFF',palette='magma')
# Out:
# C:\Users\DEEPAK VERMA\AppData\Local\Temp\ipykernel_2064\3971094953.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=fan_reviewed,x='STARS_DIFF',palette='magma')
# <Axes: xlabel='STARS_DIFF', ylabel='count'>

# %%
fan_reviewed[fan_reviewed['STARS_DIFF']==1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %% [markdown]
# # Part 2

# %%
all_sites = pd.read_csv("C:\\Users\\DEEPAK VERMA\\OneDrive\\Desktop\\all_sites_scores.csv")
all_sites
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.3+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %%
plt.figure(figsize=(10,6),dpi=180)

sns.scatterplot(data=all_sites,x='RottenTomatoes',y='RottenTomatoes_User')
plt.ylim(0,100)
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
all_sites['Rotten_Diff']=all_sites['RottenTomatoes'] - all_sites['RottenTomatoes_User']

# %%
all_sites
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
all_sites['Rotten_Diff'].apply(abs).mean()
# Out:
# 15.095890410958905

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=all_sites,x='Rotten_Diff',kde=True)
# Out:
# <Axes: xlabel='Rotten_Diff', ylabel='Count'>

# %%
plt.figure(figsize=(14,8),dpi=200)
sns.histplot(data=all_sites,x=all_sites['Rotten_Diff'].apply(abs),kde=True)
# Out:
# <Axes: xlabel='Rotten_Diff', ylabel='Count'>

# %%
all_sites.nsmallest(5,'Rotten_Diff')
# Out:
#                           FILM  RottenTomatoes  RottenTomatoes_User  \
# 3       Do You Believe? (2015)              18                   84
# 85           Little Boy (2015)              20                   81
# 105    Hitman: Agent 47 (2015)               7                   49
# 134    The Longest Ride (2015)              31                   73
# 125  The Wedding Ringer (2015)              27                   66
#
#      Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 3            22              4.7   5.4                          31
# 85           30              5.9   7.4                          38
# 105          28              3.3   5.9                          67
# 134          33              4.8   7.2                          49
# 125          35              3.3   6.7                         126
#
#      IMDB_user_vote_count  Rotten_Diff
# 3                    3136          -66
# 85                   5927          -61
# ...

# %%
all_sites.nsmallest(5,'Rotten_Diff')['FILM']
# Out:
# 3         Do You Believe? (2015)
# 85             Little Boy (2015)
# 105      Hitman: Agent 47 (2015)
# 134      The Longest Ride (2015)
# 125    The Wedding Ringer (2015)
# Name: FILM, dtype: object

# %%
all_sites.nlargest(5,'Rotten_Diff')['FILM']
# Out:
# 69                    Mr. Turner (2014)
# 112                   It Follows (2015)
# 115            While We're Young (2015)
# 37                 Welcome to Me (2015)
# 40     I'll See You In My Dreams (2015)
# Name: FILM, dtype: object

# %%
sns.scatterplot(data=all_sites,x='Metacritic',y='Metacritic_User')
plt.ylim(0,10)
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
sns.scatterplot(data=all_sites,x='Metacritic_user_vote_count',y='IMDB_user_vote_count')
# Out:
# <Axes: xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %%
all_sites.nlargest(1,'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff
# 14                334164           -2

# %%
all_sites.nlargest(1,'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff
# 88                292023            9

# %% [markdown]
# # Part 3

# %%
df = pd.merge(fandango,all_sites,on='FILM',how='inner')
df
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %%
df.describe()
# Out:
#             STARS      RATING         VOTES  RottenTomatoes  \
# count  145.000000  145.000000    145.000000      145.000000
# mean     4.086207    3.841379   3817.696552       60.634483
# std      0.541169    0.502437   6368.668671       30.161098
# min      3.000000    2.700000     35.000000        5.000000
# 25%      3.500000    3.500000    218.000000       31.000000
# 50%      4.000000    3.900000   1430.000000       63.000000
# 75%      4.500000    4.200000   4279.000000       89.000000
# max      5.000000    4.800000  34846.000000      100.000000
#
#        RottenTomatoes_User  Metacritic  Metacritic_User        IMDB  \
# count           145.000000  145.000000       145.000000  145.000000
# mean             63.696552   58.696552         6.508966    6.729655
# std              19.974749   19.538183         1.510883    0.957944
# min              20.000000   13.000000         2.400000    4.000000
# 25%              50.000000   43.000000         5.700000    6.300000
# ...

# %%
df.describe().transpose()['max']
# Out:
# STARS                              5.0
# RATING                             4.8
# VOTES                          34846.0
# RottenTomatoes                   100.0
# RottenTomatoes_User               94.0
# Metacritic                        94.0
# Metacritic_User                    9.6
# IMDB                               8.6
# Metacritic_user_vote_count      2375.0
# IMDB_user_vote_count          334164.0
# Rotten_Diff                       42.0
# Name: max, dtype: float64

# %%
df['RT_Norm']=np.round(df['RottenTomatoes']/20,1)
df['RTU_Norm']=np.round(df['RottenTomatoes_User']/20,1)

# %%
df['Meta_Norm']=np.round(df['Metacritic']/20,1)
df['Meta_U_Norm']=np.round(df['Metacritic_User']/2,1)

# %%
df['IMDB_Norm']=np.round(df['IMDB']/2,1)

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff  RT_Norm  \
# 0                         778                179506          -17      1.2
# ...

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Rotten_Diff',
#        'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm'],
#       dtype='object')

# %%
norm_scores = df.drop(['FILM','VOTES','YEAR','RottenTomatoes','RottenTomatoes_User','Metacritic','Metacritic_User','IMDB','Metacritic_user_vote_count','IMDB_user_vote_count'],axis=1)
norm_scores.head()
# Out:
#    STARS  RATING  Rotten_Diff  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  \
# 0    4.0     3.9          -17      1.2       2.1        2.3          1.6
# 1    4.5     4.5          -10      3.6       4.0        3.0          3.5
# 2    5.0     4.8          -13      3.6       4.2        3.6          3.3
# 3    5.0     4.8           -3      4.0       4.2        3.4          3.4
# 4    4.5     4.5            8      4.9       4.5        4.7          4.4
#
#    IMDB_Norm
# 0        2.1
# 1        3.6
# 2        3.7
# 3        3.7
# 4        4.3

# %%
plt.figure(figsize=(10,6),dpi=159)
sns.kdeplot(data= norm_scores,x='STARS',clip=[0,5],fill=True,label='STARS')
sns.kdeplot(data= norm_scores,x='RATING',clip=[0,5],fill=True,label='RATING')
sns.kdeplot(data= norm_scores,x='Rotten_Diff',clip=[0,5],fill=True,label='Rotten_Diff')
sns.kdeplot(data= norm_scores,x='RT_Norm',clip=[0,5],fill=True,label='RT_Norm')
sns.kdeplot(data= norm_scores,x='RTU_Norm',clip=[0,5],fill=True,label='RTU_Norm')
sns.kdeplot(data= norm_scores,x='Meta_Norm',clip=[0,5],fill=True,label='Meta_Norm')
sns.kdeplot(data= norm_scores,x='Meta_U_Norm',clip=[0,5],fill=True,label='Meta_U_Norm')
sns.kdeplot(data= norm_scores,x='IMDB_Norm',clip=[0,5],fill=True,label='IMDB_Norm')
plt.legend()

# %%
sns.displot(data= norm_scores,palette='Dark2')
plt.xlim(0,5)
# Out:
# (0.0, 5.0)

# %%
sns.kdeplot(data= norm_scores,palette='Dark2',fill=True)
plt.xlim(0.0,6.5    )
# Out:
# (0.0, 6.5)

# %%
plt.figure(figsize=(15,8),dpi=159)

sns.histplot(norm_scores,palette='Dark2')
plt.xlim(0,6)
# Out:
# (0.0, 6.0)

# %%
sns.clustermap(norm_scores,cmap='magma',col_cluster=False)

# %%
norm_scores.columns
# Out:
# Index(['STARS', 'RATING', 'Rotten_Diff', 'RT_Norm', 'RTU_Norm', 'Meta_Norm',
#        'Meta_U_Norm', 'IMDB_Norm'],
#       dtype='object')

# %%
norm_films = df[['FILM','STARS', 'RATING', 'Rotten_Diff', 'RT_Norm', 'RTU_Norm', 'Meta_Norm',
       'Meta_U_Norm', 'IMDB_Norm']]

# %%
worst_films= norm_films.nsmallest(10,'RT_Norm')
worst_films
# Out:
#                              FILM  STARS  RATING  Rotten_Diff  RT_Norm  \
# 49  Paul Blart: Mall Cop 2 (2015)    3.5     3.5          -31      0.2
# 25                 Taken 3 (2015)    4.5     4.1          -37      0.4
# 28          Fantastic Four (2015)    3.0     2.7          -11      0.4
# 54             Hot Pursuit (2015)    4.0     3.7          -29      0.4
# 84        Hitman: Agent 47 (2015)    4.0     3.9          -42      0.4
# 50       The Boy Next Door (2015)    4.0     3.6          -25      0.5
# 77             Seventh Son (2015)    3.5     3.2          -23      0.6
# 78               Mortdecai (2015)    3.5     3.2          -18      0.6
# 83              Sinister 2 (2015)    3.5     3.3          -21      0.6
# 87     Unfinished Business (2015)    3.5     3.2          -16      0.6
#
#     RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 49       1.8        0.6          1.2        2.2
# 25       2.3        1.3          2.3        3.0
# ...

# %%
plt.figure(figsize=(15,8),dpi=159)

sns.kdeplot(data=worst_films,clip=[0,5],shade=True,palette='Set1')
# Out:
# C:\Users\DEEPAK VERMA\AppData\Local\Temp\ipykernel_2064\4273322123.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=worst_films,clip=[0,5],shade=True,palette='Set1')
# <Axes: ylabel='Density'>

# %%
worst_films.head()
# Out:
#                              FILM  STARS  RATING  Rotten_Diff  RT_Norm  \
# 49  Paul Blart: Mall Cop 2 (2015)    3.5     3.5          -31      0.2
# 25                 Taken 3 (2015)    4.5     4.1          -37      0.4
# 28          Fantastic Four (2015)    3.0     2.7          -11      0.4
# 54             Hot Pursuit (2015)    4.0     3.7          -29      0.4
# 84        Hitman: Agent 47 (2015)    4.0     3.9          -42      0.4
#
#     RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 49       1.8        0.6          1.2        2.2
# 25       2.3        1.3          2.3        3.0
# 28       1.0        1.4          1.2        2.0
# 54       1.8        1.6          1.8        2.4
# 84       2.4        1.4          1.6        3.0
